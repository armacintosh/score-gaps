# %%
# imports
import sys
import utils
from dotenv import load_dotenv
import os
import pandas as pd
import numpy as np
import config
config = config.assessment_sources
SPREADSHEET_ID_SAT = config['spreadsheet_id_SAT']
SPREADSHEET_ID_NAEP = config['spreadsheet_id_NAEP']
SPREADSHEET_ID_LSAT = config['spreadsheet_id_LSAT']
SPREADSHEET_ID_GRE = config['spreadsheet_id_GRE']
SPREADSHEET_ID_GMAT = config['spreadsheet_id_GMAT']
SPREADSHEET_ID_Casper = config['spreadsheet_id_Casper']
SPREADSHEET_ID_AAMC = config['spreadsheet_id_AAMC']
SPREADSHEET_ID_Mapping = config['spreadsheet_id_Mapping']

# %%
# connect to google sheets and get dfs
service = utils.connect_to_google('sheets')

# make a list of all the spreadsheet ids in config.assessment_sources
# for each spreadsheet id, get the data from the 'Data' tab
df_sat = utils.read_google_sheet(service, SPREADSHEET_ID_SAT, 'Data')
df_naep = utils.read_google_sheet(service, SPREADSHEET_ID_NAEP, 'Data')
df_lsat = utils.read_google_sheet(service, SPREADSHEET_ID_LSAT, 'Data')
df_gre = utils.read_google_sheet(service, SPREADSHEET_ID_GRE, 'Data')
df_gmat = utils.read_google_sheet(service, SPREADSHEET_ID_GMAT, 'Data')
df_casper = utils.read_google_sheet(service, SPREADSHEET_ID_Casper, 'Data')
df_aamc = utils.read_google_sheet(service, SPREADSHEET_ID_AAMC, 'Data')
df_Mapping = utils.read_google_sheet(service, SPREADSHEET_ID_Mapping, 'Variable')

# %%
# add N as last column to df_naep
df_naep['N'] = np.nan

# if a cell in df_mapping is empty put it as missing value
df_Mapping = df_Mapping.replace(r'^\s*$', np.nan, regex=True)

dfs_dict = {'df_sat': df_sat, 
            'df_naep': df_naep, 
            'df_lsat': df_lsat, 
            'df_gre': df_gre, 
            'df_gmat': df_gmat, 
            'df_casper': df_casper, 
            'df_aamc': df_aamc}

# %%
# create a mapping dictionay: 
mapping_table = df_Mapping
# Initialize a dictionary of dictionaries to store mappings
mappings = {}

# Iterate over each column in the mapping table (excluding 'CommonTerm' and 'Column')
for col in mapping_table.columns[2:]:
    # Create an empty dictionary for each data frame
    mappings[col] = {}
    
    # Filter the mapping table for each column type (e.g., 'Race', 'Gender')
    for column in mapping_table['Column'].unique():
        filtered_table = mapping_table[mapping_table['Column'] == column]
        # Create a sub-dictionary for each column in each data frame
        mappings[col][column] = dict(zip(filtered_table[col], filtered_table['CommonTerm']))

# %%
# Standardize relevant columns in each data frame using the mappings
for name, df in dfs_dict.items():
    for column in df.columns:
        if column in mappings[name]:  # Check if there's a mapping for this column
            df[column] = df[column].map(mappings[name][column]).fillna(df[column])

# Check the results
for name, df in dfs_dict.items():
    print(f"{name} standardized:")
    print(df)
    print()

# %%
# Combine all the dataframes from the df_dict into one dataframe
combined_df = pd.concat(dfs_dict.values(), ignore_index=True)

# %%
# Create the dictionary
variable_grouping_dict = {}

# Iterate through each unique value in the 'Variable' column
for variable in combined_df['Variable'].unique():
	# Get the unique 'Grouping' values for the current 'Variable'
	groupings = combined_df[combined_df['Variable'] == variable]['Grouping'].unique()
	# Store in the dictionary
	variable_grouping_dict[variable] = list(groupings)

# Print the dictionary
print(variable_grouping_dict)

# %%
# clean up data

# set column types  for combined_df
column_types = {
    'Variable': 'category',
    'Subject': 'category',
    'Year': 'int64',
    'Jurisdiction': 'category',
    'Grouping': 'category',
    'Mean': 'float64',
    'SD': 'float64',
    'N': 'float64'
}

# Set the types of each column in combined_df using the dictionary
combined_df = combined_df.astype(column_types)

# Verify the column types
print(combined_df.dtypes)

# %% [markdown]
# # Cohen's D

# %%
import pandas as pd
import numpy as np

# Reference groups dictionary
reference_groups = {
	'Gender': 'Female',
	'Race/Ethnicity': 'White'
}

# Function to calculate Cohen's d
def cohen_d(mean1, mean2, sd1, sd2):
	pooled_sd = np.sqrt((sd1 ** 2 + sd2 ** 2) / 2)
	return (mean2 - mean1) / pooled_sd

# Function to calculate Cohen's d effect size across 'Grouping'
def calculate_cohens_d(combined_df, reference_groups):
	results = []

	# Iterate through each unique combination of Variable, Subject, Year, and Jurisdiction
	for (variable, subject, year, jurisdiction) in combined_df.groupby(['Variable', 'Subject', 'Year', 'Jurisdiction']).groups.keys():
		# Check if the variable is in the reference_groups dictionary
		if variable not in reference_groups:
			continue
		
		subset_df = combined_df[(combined_df['Variable'] == variable) &
								(combined_df['Subject'] == subject) &
								(combined_df['Year'] == year) &
								(combined_df['Jurisdiction'] == jurisdiction)]
		
		# Identify the reference group
		reference_group = reference_groups[variable]
		
		reference_row = subset_df[subset_df['Grouping'] == reference_group]
		if reference_row.empty:
			continue
		
		mean_ref = reference_row['Mean'].values[0]
		sd_ref = reference_row['SD'].values[0]
		
		# Calculate Cohen's d for each group compared to the reference group
		for _, row in subset_df.iterrows():
			if row['Grouping'] == reference_group:
				continue
			
			mean_grp = row['Mean']
			sd_grp = row['SD']
			d = cohen_d(mean_ref, mean_grp, sd_ref, sd_grp)
			
			results.append({
				'Variable': variable,
				'Subject': subject,
				'Year': year,
				'Jurisdiction': jurisdiction,
				'Reference Group': reference_group,
				'Comparison Group': row['Grouping'],
				'Cohen\'s d': d
			})
	
	return pd.DataFrame(results)

# Example usage
# combined_df = pd.read_csv('path_to_your_csv_file.csv')  # Load your DataFrame
cohens_d_df = calculate_cohens_d(combined_df, reference_groups)
print(cohens_d_df)

# %%
merged_df.columns
# Out:
# Index(['Variable', 'Subject', 'Grade', 'Year', 'Jurisdiction', 'Grouping',
#        'Mean', 'SD', 'N', 'Cohen's d'],
#       dtype='object')

# %%
# Rename 'Comparison Group' to 'Grouping' in cohens_d_df to facilitate the merge
cohens_d_df = cohens_d_df.rename(columns={'Comparison Group': 'Grouping'})

# Keep only the 'Cohen's d' column in cohens_d_df
cohens_d_df = cohens_d_df[['Variable', 'Subject', 'Year', 'Jurisdiction', 'Grouping', "Cohen's d"]]

# Merge cohens_d_df with combined_df on the relevant columns
merged_df = combined_df.merge(cohens_d_df, on=['Variable', 'Subject', 'Year', 'Jurisdiction', 'Grouping'], how='left')

# Assign a Cohen's d value of 0 where the reference category matches the grouping
for variable, reference_group in reference_groups.items():
    merged_df.loc[(merged_df['Variable'] == variable) & (merged_df['Grouping'] == reference_group), "Cohen's d"] = 0

# Verify the result
print(merged_df)

# %%
# write merged_df to a csv file in data folder
merged_df.to_csv('data/merged_data.csv', index=False)

# %%
# Order of subjects for the table
subjects_ordered = [
    'NAEP - Science - 4',
    'NAEP - Reading - 4',
    'NAEP - Reading - 8',
    'NAEP - Science - 8',
    'NAEP - Science - 12',
    'NAEP - Reading - 12',
    'SAT - Total',
    'SAT - Math',
    'SAT - ERW',
    'Casper',
    'MCAT Total',
    'MCAT CPBS',
    'MCAT CARS',
    'MCAT BBLS',
    'MCAT PSBB',
    'AAMC - GPA Total',
    'AAMC - GPA Science',
    'AAMC - GPA Non-Science',
    'GRE - Analytical Writing',
    'GRE - Quantitative',
    'GRE - Verbal',
    'GMAT - Total Score',
    'LSAT'
]

# Define the race order
race_order = [
    'Black',
    'Hispanic',
    'Asian',
    'American Indian/Alaska Native',
    'Native Hawaiian/Other Pacific Islander',
    'Another Race/Ethnicity',
    'Multiple Races/Ethnicities',
    'White'
]

# %%
# Filtering the dataframe to only include 'Variable' value 'Race/Ethnicity' and 'Jurisdiction' = 'US'
filtered_df = merged_df[
    (merged_df['Variable'] == 'Race/Ethnicity') & 
    (merged_df['Jurisdiction'] == 'US')
]

# Convert year into category using .loc to avoid SettingWithCopyWarning
filtered_df.loc[:, 'Year'] = filtered_df['Year'].astype('category')

# Creating a pivot table with 'Grouping' as columns,
# 'Subject' and 'Year' as rows, and 'Cohen\'s d' as values
pivot_df = filtered_df.pivot_table(
    index=['Subject', 'Year'], 
    columns='Grouping', 
    values="Cohen's d",
    aggfunc='first'  # This picks the first value if there are duplicates
)

# Reindex the rows to match the specified order
pivot_df = pivot_df.reindex(subjects_ordered, level=0)

# Reorder the columns to match the race order
pivot_df = pivot_df[race_order]

# Combine 'Subject' and 'Year' into a single column for the index
pivot_df.index = pivot_df.index.map(lambda x: f'{x[0]} ({x[1]})')

# Resetting the index for a cleaner look (optional)
pivot_df = pivot_df.reset_index()

# Display the result
pivot_df
# Out:
# Grouping                            index     Black  Hispanic     Asian  \
# 0               NAEP - Science - 4 (2019) -0.996127 -0.734515  0.146024
# 1               NAEP - Reading - 4 (2019) -0.734293 -0.583584  0.248755
# 2               NAEP - Reading - 8 (2019) -0.791885 -0.570780  0.315898
# 3               NAEP - Science - 8 (2019) -1.003581 -0.744069  0.109537
# 4              NAEP - Science - 12 (2019) -1.033937 -0.727622  0.136405
# 5              NAEP - Reading - 12 (2019) -0.781345 -0.524361  0.106373
# 6                      SAT - Total (2023) -0.787330 -0.628959  0.619910
# 7                       SAT - Math (2023) -0.745902 -0.581967  0.770492
# 8                        SAT - ERW (2023) -0.763636 -0.618182  0.390909
# 9                           Casper (2022) -0.705919 -0.412546 -0.021598
# 10                          Casper (2024) -0.613128 -0.392840 -0.057219
# 11                      MCAT Total (2023) -1.098952 -0.794089  0.144364
# 12                       MCAT CPBS (2023) -0.927980 -0.630706  0.290861
# 13                       MCAT CARS (2023) -0.999261 -0.828862 -0.076866
# 14                       MCAT BBLS (2023) -0.980361 -0.641223  0.150917
# 15                       MCAT PSBB (2023) -0.854965 -0.651695  0.115385
# 16                AAMC - GPA Total (2023) -0.897891 -0.609569  0.000000
# 17              AAMC - GPA Science (2023) -0.918146 -0.581061  0.026645
# 18          AAMC - GPA Non-Science (2023) -0.645646 -0.432872  0.000000
# 19        GRE - Analytical Writing (2023) -0.704664 -0.352332  0.125000
# 20              GRE - Quantitative (2023) -0.813333 -0.447330  0.446165
# 21                    GRE - Verbal (2023) -0.706604 -0.439961  0.025954
# 22              GMAT - Total Score (2023) -1.172646 -0.731452  0.325090
# 23                            LSAT (2023) -1.087908 -0.765184  0.083702
#
# Grouping  American Indian/Alaska Native  \
# 0                             -0.645576
# 1                             -0.698340
# 2                             -0.678497
# 3                             -0.671662
# 4                             -0.562197
# 5                             -0.583162
# 6                             -0.819005
# 7                             -0.729508
# 8                             -0.836364
# 9                             -0.435009
# 10                            -0.341730
# 11                            -1.248158
# 12                            -1.111111
# 13                            -0.960332
# 14                            -1.192308
# 15                            -1.016671
# 16                            -0.771698
# 17                            -0.828671
# 18                            -0.611665
# 19                            -0.352332
# 20                            -0.442943
# 21                            -0.399914
# 22                            -0.859166
# 23                            -0.886527
#
# Grouping  Native Hawaiian/Other Pacific Islander  Another Race/Ethnicity  \
# 0                                      -0.611066                     NaN
# 1                                      -0.511530                     NaN
# 2                                      -0.540574                     NaN
# 3                                      -0.789898                     NaN
# 4                                      -0.680290                     NaN
# 5                                      -0.442316                     NaN
# 6                                      -0.710407                     NaN
# 7                                      -0.655738                     NaN
# 8                                      -0.700000                     NaN
# 9                                            NaN               -0.068176
# 10                                           NaN               -0.095488
# 11                                     -0.714852               -0.288075
# 12                                     -0.516016               -0.140157
# 13                                     -0.680000               -0.461197
# 14                                     -0.653574               -0.213741
# 15                                     -0.629198               -0.181548
# 16                                     -0.706953               -0.228741
# 17                                     -0.740883               -0.226959
# 18                                     -0.391480               -0.117444
# 19                                     -0.117444                0.000000
# 20                                     -0.331119                0.000000
# 21                                     -0.433302                0.025436
# 22                                     -0.150935                0.081272
# 23                                     -0.755626                     NaN
#
# Grouping  Multiple Races/Ethnicities  White
# 0                          -0.126202    0.0
# 1                          -0.124840    0.0
# 2                          -0.146389    0.0
# 3                          -0.193384    0.0
# 4                          -0.139099    0.0
# 5                           0.002694    0.0
# 6                           0.040724    0.0
# 7                           0.024590    0.0
# 8                           0.054545    0.0
# 9                                NaN    0.0
# 10                               NaN    0.0
# 11                         -0.307659    0.0
# 12                         -0.245275    0.0
# 13                         -0.301404    0.0
# 14                         -0.290477    0.0
# 15                         -0.254168    0.0
# 16                         -0.315519    0.0
# 17                         -0.323387    0.0
# 18                         -0.225414    0.0
# 19                               NaN    0.0
# 20                               NaN    0.0
# 21                               NaN    0.0
# 22                               NaN    0.0
# 23                         -0.314324    0.0

# %%
# Apply a color gradient using a predefined palette
# cmap: the color map you want to use, e.g., 'coolwarm', 'viridis', 'RdYlBu', etc.
# axis=None applies the gradient cell by cell
styled_df = pivot_df.style.background_gradient(cmap='RdYlBu', axis=None)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_c2f1c_row0_col1, #T_c2f1c_row3_col1, #T_c2f1c_row13_col1 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_c2f1c_row0_col2, #T_c2f1c_row1_col1, #T_c2f1c_row7_col4, #T_c2f1c_row22_col2 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_c2f1c_row0_col3, #T_c2f1c_row11_col3 {
#   background-color: #b0dcea;
#   color: #000000;
# }
# #T_c2f1c_row0_col4, #T_c2f1c_row14_col2, #T_c2f1c_row18_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_c2f1c_row0_col5, #T_c2f1c_row10_col1, #T_c2f1c_row16_col2, #T_c2f1c_row18_col4 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_c2f1c_row0_col6, #T_c2f1c_row1_col6, #T_c2f1c_row2_col6, #T_c2f1c_row3_col6, #T_c2f1c_row4_col6, #T_c2f1c_row5_col6, #T_c2f1c_row6_col6, #T_c2f1c_row7_col6, #T_c2f1c_row8_col6, #T_c2f1c_row9_col5, #T_c2f1c_row9_col7, #T_c2f1c_row10_col5, #T_c2f1c_row10_col7, #T_c2f1c_row19_col7, #T_c2f1c_row20_col7, #T_c2f1c_row21_col7, #T_c2f1c_row22_col7, #T_c2f1c_row23_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c2f1c_row0_col7, #T_c2f1c_row1_col7 {
#   background-color: #edf8df;
#   color: #000000;
# }
# #T_c2f1c_row0_col8, #T_c2f1c_row1_col8, #T_c2f1c_row2_col8, #T_c2f1c_row3_col8, #T_c2f1c_row4_col8, #T_c2f1c_row5_col7, #T_c2f1c_row5_col8, #T_c2f1c_row6_col8, #T_c2f1c_row7_col8, #T_c2f1c_row8_col8, #T_c2f1c_row9_col8, #T_c2f1c_row10_col8, #T_c2f1c_row11_col8, #T_c2f1c_row12_col8, #T_c2f1c_row13_col8, #T_c2f1c_row14_col8, #T_c2f1c_row15_col8, #T_c2f1c_row16_col3, #T_c2f1c_row16_col8, #T_c2f1c_row17_col8, #T_c2f1c_row18_col3, #T_c2f1c_row18_col8, #T_c2f1c_row19_col6, #T_c2f1c_row19_col8, #T_c2f1c_row20_col6, #T_c2f1c_row20_col8, #T_c2f1c_row21_col8, #T_c2f1c_row22_col8, #T_c2f1c_row23_col8 {
#   background-color: #d6eef5;
#   color: #000000;
# }
# #T_c2f1c_row1_col2, #T_c2f1c_row5_col4, #T_c2f1c_row7_col2, #T_c2f1c_row17_col2 {
#   background-color: #fdbd6f;
#   color: #000000;
# }
# #T_c2f1c_row1_col3 {
#   background-color: #94c7df;
#   color: #000000;
# }
# #T_c2f1c_row1_col4, #T_c2f1c_row8_col5 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_c2f1c_row1_col5 {
#   background-color: #fece7f;
#   color: #000000;
# }
# #T_c2f1c_row2_col1, #T_c2f1c_row11_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_c2f1c_row2_col2 {
#   background-color: #fdbf71;
#   color: #000000;
# }
# #T_c2f1c_row2_col3 {
#   background-color: #81b7d7;
#   color: #000000;
# }
# #T_c2f1c_row2_col4, #T_c2f1c_row4_col5, #T_c2f1c_row13_col5 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_c2f1c_row2_col5 {
#   background-color: #fdc778;
#   color: #000000;
# }
# #T_c2f1c_row2_col7, #T_c2f1c_row22_col5 {
#   background-color: #f1fad9;
#   color: #000000;
# }
# #T_c2f1c_row3_col2, #T_c2f1c_row7_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_c2f1c_row3_col3, #T_c2f1c_row15_col3 {
#   background-color: #b9e0ed;
#   color: #000000;
# }
# #T_c2f1c_row3_col4 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_c2f1c_row3_col5, #T_c2f1c_row6_col1 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_c2f1c_row3_col7 {
#   background-color: #f8fccb;
#   color: #000000;
# }
# #T_c2f1c_row4_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_c2f1c_row4_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_c2f1c_row4_col3 {
#   background-color: #b2ddeb;
#   color: #000000;
# }
# #T_c2f1c_row4_col4 {
#   background-color: #fdc173;
#   color: #000000;
# }
# #T_c2f1c_row4_col7, #T_c2f1c_row12_col6 {
#   background-color: #f0f9db;
#   color: #000000;
# }
# #T_c2f1c_row5_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_c2f1c_row5_col2 {
#   background-color: #feca7c;
#   color: #000000;
# }
# #T_c2f1c_row5_col3 {
#   background-color: #bbe1ed;
#   color: #000000;
# }
# #T_c2f1c_row5_col5, #T_c2f1c_row20_col4, #T_c2f1c_row21_col2 {
#   background-color: #fee090;
#   color: #000000;
# }
# #T_c2f1c_row6_col2, #T_c2f1c_row12_col2, #T_c2f1c_row15_col5 {
#   background-color: #fdb164;
#   color: #000000;
# }
# #T_c2f1c_row6_col3 {
#   background-color: #4065ac;
#   color: #f1f1f1;
# }
# #T_c2f1c_row6_col4 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_c2f1c_row6_col5, #T_c2f1c_row9_col1, #T_c2f1c_row16_col5, #T_c2f1c_row19_col1, #T_c2f1c_row21_col1 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_c2f1c_row6_col7 {
#   background-color: #cbe9f2;
#   color: #000000;
# }
# #T_c2f1c_row7_col3 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_c2f1c_row7_col5, #T_c2f1c_row14_col5, #T_c2f1c_row15_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_c2f1c_row7_col7, #T_c2f1c_row17_col3, #T_c2f1c_row21_col3, #T_c2f1c_row21_col6 {
#   background-color: #cfebf3;
#   color: #000000;
# }
# #T_c2f1c_row8_col1, #T_c2f1c_row23_col2 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_c2f1c_row8_col2 {
#   background-color: #fdb366;
#   color: #000000;
# }
# #T_c2f1c_row8_col3 {
#   background-color: #6ea6ce;
#   color: #f1f1f1;
# }
# #T_c2f1c_row8_col4 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_c2f1c_row8_col7 {
#   background-color: #c7e7f1;
#   color: #000000;
# }
# #T_c2f1c_row9_col2 {
#   background-color: #fee496;
#   color: #000000;
# }
# #T_c2f1c_row9_col3 {
#   background-color: #dcf1f7;
#   color: #000000;
# }
# #T_c2f1c_row9_col4, #T_c2f1c_row18_col2, #T_c2f1c_row21_col5 {
#   background-color: #fee192;
#   color: #000000;
# }
# #T_c2f1c_row9_col6 {
#   background-color: #e5f5ef;
#   color: #000000;
# }
# #T_c2f1c_row10_col2, #T_c2f1c_row18_col5 {
#   background-color: #fee79b;
#   color: #000000;
# }
# #T_c2f1c_row10_col3 {
#   background-color: #e2f4f4;
#   color: #000000;
# }
# #T_c2f1c_row10_col4 {
#   background-color: #feefa6;
#   color: #000000;
# }
# #T_c2f1c_row10_col6 {
#   background-color: #e9f6e8;
#   color: #000000;
# }
# #T_c2f1c_row11_col1 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_c2f1c_row11_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c2f1c_row11_col5 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_c2f1c_row11_col6, #T_c2f1c_row14_col7 {
#   background-color: #fff7b3;
#   color: #000000;
# }
# #T_c2f1c_row11_col7 {
#   background-color: #fff5af;
#   color: #000000;
# }
# #T_c2f1c_row12_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_c2f1c_row12_col3 {
#   background-color: #87bdd9;
#   color: #000000;
# }
# #T_c2f1c_row12_col4 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_c2f1c_row12_col5 {
#   background-color: #fecc7e;
#   color: #000000;
# }
# #T_c2f1c_row12_col7 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_c2f1c_row13_col2, #T_c2f1c_row17_col4 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_c2f1c_row13_col3 {
#   background-color: #e6f5ed;
#   color: #000000;
# }
# #T_c2f1c_row13_col4 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_c2f1c_row13_col6 {
#   background-color: #feda8a;
#   color: #000000;
# }
# #T_c2f1c_row13_col7 {
#   background-color: #fff6b1;
#   color: #000000;
# }
# #T_c2f1c_row14_col1 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_c2f1c_row14_col3 {
#   background-color: #aedbea;
#   color: #000000;
# }
# #T_c2f1c_row14_col4 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_c2f1c_row14_col6 {
#   background-color: #fbfdc7;
#   color: #000000;
# }
# #T_c2f1c_row15_col1, #T_c2f1c_row22_col4 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_c2f1c_row15_col4 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_c2f1c_row15_col6 {
#   background-color: #f6fbd0;
#   color: #000000;
# }
# #T_c2f1c_row15_col7 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_c2f1c_row16_col1 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_c2f1c_row16_col4 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_c2f1c_row16_col6, #T_c2f1c_row17_col6, #T_c2f1c_row18_col7 {
#   background-color: #fdfec2;
#   color: #000000;
# }
# #T_c2f1c_row16_col7, #T_c2f1c_row23_col7 {
#   background-color: #fff3ad;
#   color: #000000;
# }
# #T_c2f1c_row17_col1 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_c2f1c_row17_col5 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_c2f1c_row17_col7 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_c2f1c_row18_col6, #T_c2f1c_row19_col5 {
#   background-color: #ecf8e2;
#   color: #000000;
# }
# #T_c2f1c_row19_col2, #T_c2f1c_row19_col4 {
#   background-color: #feeda4;
#   color: #000000;
# }
# #T_c2f1c_row19_col3 {
#   background-color: #b4de
